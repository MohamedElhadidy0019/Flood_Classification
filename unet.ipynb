# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flood-area-segmentation/metadata.csv
# /kaggle/input/flood-area-segmentation/Mask/1017.png
# /kaggle/input/flood-area-segmentation/Mask/2015.png
# /kaggle/input/flood-area-segmentation/Mask/1084.png
# /kaggle/input/flood-area-segmentation/Mask/2021.png
# /kaggle/input/flood-area-segmentation/Mask/1012.png
# /kaggle/input/flood-area-segmentation/Mask/48.png
# /kaggle/input/flood-area-segmentation/Mask/3012.png
# /kaggle/input/flood-area-segmentation/Mask/1037.png
# /kaggle/input/flood-area-segmentation/Mask/2009.png
# /kaggle/input/flood-area-segmentation/Mask/1023.png
# /kaggle/input/flood-area-segmentation/Mask/3070.png
# /kaggle/input/flood-area-segmentation/Mask/37.png
# /kaggle/input/flood-area-segmentation/Mask/1048.png
# /kaggle/input/flood-area-segmentation/Mask/3068.png
# /kaggle/input/flood-area-segmentation/Mask/1000.png
# /kaggle/input/flood-area-segmentation/Mask/35.png
# /kaggle/input/flood-area-segmentation/Mask/2030.png
# /kaggle/input/flood-area-segmentation/Mask/1081.png
# /kaggle/input/flood-area-segmentation/Mask/3002.png
# /kaggle/input/flood-area-segmentation/Mask/3047.png
# /kaggle/input/flood-area-segmentation/Mask/2013.png
# /kaggle/input/flood-area-segmentation/Mask/2011.png
# /kaggle/input/flood-area-segmentation/Mask/1004.png
# /kaggle/input/flood-area-segmentation/Mask/3052.png
# /kaggle/input/flood-area-segmentation/Mask/3058.png
# /kaggle/input/flood-area-segmentation/Mask/1032.png
# /kaggle/input/flood-area-segmentation/Mask/3030.png
# /kaggle/input/flood-area-segmentation/Mask/2003.png
# /kaggle/input/flood-area-segmentation/Mask/2051.png
# /kaggle/input/flood-area-segmentation/Mask/3061.png
# /kaggle/input/flood-area-segmentation/Mask/3053.png
# /kaggle/input/flood-area-segmentation/Mask/2041.png
# /kaggle/input/flood-area-segmentation/Mask/3028.png
# /kaggle/input/flood-area-segmentation/Mask/1064.png
# /kaggle/input/flood-area-segmentation/Mask/1072.png
# /kaggle/input/flood-area-segmentation/Mask/3098.png
# /kaggle/input/flood-area-segmentation/Mask/3082.png
# /kaggle/input/flood-area-segmentation/Mask/3025.png
# /kaggle/input/flood-area-segmentation/Mask/11.png
# /kaggle/input/flood-area-segmentation/Mask/1036.png
# /kaggle/input/flood-area-segmentation/Mask/1010.png
# /kaggle/input/flood-area-segmentation/Mask/2026.png
# /kaggle/input/flood-area-segmentation/Mask/1041.png
# /kaggle/input/flood-area-segmentation/Mask/3056.png
# /kaggle/input/flood-area-segmentation/Mask/1071.png
# /kaggle/input/flood-area-segmentation/Mask/31.png
# /kaggle/input/flood-area-segmentation/Mask/1018.png
# /kaggle/input/flood-area-segmentation/Mask/2017.png
# /kaggle/input/flood-area-segmentation/Mask/4.png
# /kaggle/input/flood-area-segmentation/Mask/2028.png
# /kaggle/input/flood-area-segmentation/Mask/2037.png
# /kaggle/input/flood-area-segmentation/Mask/3051.png
# /kaggle/input/flood-area-segmentation/Mask/43.png
# /kaggle/input/flood-area-segmentation/Mask/3066.png
# /kaggle/input/flood-area-segmentation/Mask/2040.png
# /kaggle/input/flood-area-segmentation/Mask/1067.png
# /kaggle/input/flood-area-segmentation/Mask/2053.png
# /kaggle/input/flood-area-segmentation/Mask/3015.png
# /kaggle/input/flood-area-segmentation/Mask/40.png
# /kaggle/input/flood-area-segmentation/Mask/3072.png
# /kaggle/input/flood-area-segmentation/Mask/1006.png
# /kaggle/input/flood-area-segmentation/Mask/3005.png
# /kaggle/input/flood-area-segmentation/Mask/33.png
# /kaggle/input/flood-area-segmentation/Mask/3090.png
# /kaggle/input/flood-area-segmentation/Mask/3089.png
# /kaggle/input/flood-area-segmentation/Mask/9.png
# /kaggle/input/flood-area-segmentation/Mask/2012.png
# /kaggle/input/flood-area-segmentation/Mask/1045.png
# /kaggle/input/flood-area-segmentation/Mask/2007.png
# /kaggle/input/flood-area-segmentation/Mask/1055.png
# /kaggle/input/flood-area-segmentation/Mask/1039.png
# /kaggle/input/flood-area-segmentation/Mask/2044.png
# /kaggle/input/flood-area-segmentation/Mask/1027.png
# /kaggle/input/flood-area-segmentation/Mask/3038.png
# /kaggle/input/flood-area-segmentation/Mask/1077.png
# /kaggle/input/flood-area-segmentation/Mask/1025.png
# /kaggle/input/flood-area-segmentation/Mask/3078.png
# /kaggle/input/flood-area-segmentation/Mask/3003.png
# /kaggle/input/flood-area-segmentation/Mask/1047.png
# /kaggle/input/flood-area-segmentation/Mask/3080.png
# /kaggle/input/flood-area-segmentation/Mask/3034.png
# /kaggle/input/flood-area-segmentation/Mask/3062.png
# /kaggle/input/flood-area-segmentation/Mask/1054.png
# /kaggle/input/flood-area-segmentation/Mask/1038.png
# /kaggle/input/flood-area-segmentation/Mask/1078.png
# /kaggle/input/flood-area-segmentation/Mask/3045.png
# /kaggle/input/flood-area-segmentation/Mask/3042.png
# /kaggle/input/flood-area-segmentation/Mask/49.png
# /kaggle/input/flood-area-segmentation/Mask/1076.png
# /kaggle/input/flood-area-segmentation/Mask/1003.png
# /kaggle/input/flood-area-segmentation/Mask/3011.png
# /kaggle/input/flood-area-segmentation/Mask/3060.png
# /kaggle/input/flood-area-segmentation/Mask/3022.png
# /kaggle/input/flood-area-segmentation/Mask/3092.png
# /kaggle/input/flood-area-segmentation/Mask/3014.png
# /kaggle/input/flood-area-segmentation/Mask/3006.png
# /kaggle/input/flood-area-segmentation/Mask/3039.png
# /kaggle/input/flood-area-segmentation/Mask/3044.png
# /kaggle/input/flood-area-segmentation/Mask/2020.png
# /kaggle/input/flood-area-segmentation/Mask/14.png
# /kaggle/input/flood-area-segmentation/Mask/1029.png
# /kaggle/input/flood-area-segmentation/Mask/1.png
# /kaggle/input/flood-area-segmentation/Mask/1073.png
# /kaggle/input/flood-area-segmentation/Mask/3065.png
# /kaggle/input/flood-area-segmentation/Mask/1019.png
# /kaggle/input/flood-area-segmentation/Mask/3032.png
# /kaggle/input/flood-area-segmentation/Mask/3040.png
# /kaggle/input/flood-area-segmentation/Mask/39.png
# /kaggle/input/flood-area-segmentation/Mask/3020.png
# /kaggle/input/flood-area-segmentation/Mask/3077.png
# /kaggle/input/flood-area-segmentation/Mask/3031.png
# /kaggle/input/flood-area-segmentation/Mask/3071.png
# /kaggle/input/flood-area-segmentation/Mask/2052.png
# /kaggle/input/flood-area-segmentation/Mask/2034.png
# /kaggle/input/flood-area-segmentation/Mask/2029.png
# /kaggle/input/flood-area-segmentation/Mask/2005.png
# /kaggle/input/flood-area-segmentation/Mask/3055.png
# /kaggle/input/flood-area-segmentation/Mask/3018.png
# /kaggle/input/flood-area-segmentation/Mask/20.png
# /kaggle/input/flood-area-segmentation/Mask/3086.png
# /kaggle/input/flood-area-segmentation/Mask/1083.png
# /kaggle/input/flood-area-segmentation/Mask/38.png
# /kaggle/input/flood-area-segmentation/Mask/1009.png
# /kaggle/input/flood-area-segmentation/Mask/2.png
# /kaggle/input/flood-area-segmentation/Mask/1005.png
# /kaggle/input/flood-area-segmentation/Mask/1033.png
# /kaggle/input/flood-area-segmentation/Mask/3016.png
# /kaggle/input/flood-area-segmentation/Mask/10.png
# /kaggle/input/flood-area-segmentation/Mask/1070.png
# /kaggle/input/flood-area-segmentation/Mask/3096.png
# /kaggle/input/flood-area-segmentation/Mask/3087.png
# /kaggle/input/flood-area-segmentation/Mask/1008.png
# /kaggle/input/flood-area-segmentation/Mask/36.png
# /kaggle/input/flood-area-segmentation/Mask/1014.png
# /kaggle/input/flood-area-segmentation/Mask/1063.png
# /kaggle/input/flood-area-segmentation/Mask/3083.png
# /kaggle/input/flood-area-segmentation/Mask/3049.png
# /kaggle/input/flood-area-segmentation/Mask/3010.png
# /kaggle/input/flood-area-segmentation/Mask/1062.png
# /kaggle/input/flood-area-segmentation/Mask/3064.png
# /kaggle/input/flood-area-segmentation/Mask/1085.png
# /kaggle/input/flood-area-segmentation/Mask/2048.png
# /kaggle/input/flood-area-segmentation/Mask/3095.png
# /kaggle/input/flood-area-segmentation/Mask/1022.png
# /kaggle/input/flood-area-segmentation/Mask/2006.png
# /kaggle/input/flood-area-segmentation/Mask/1020.png
# /kaggle/input/flood-area-segmentation/Mask/18.png
# /kaggle/input/flood-area-segmentation/Mask/2036.png
# /kaggle/input/flood-area-segmentation/Mask/1079.png
# /kaggle/input/flood-area-segmentation/Mask/21.png
# /kaggle/input/flood-area-segmentation/Mask/12.png
# /kaggle/input/flood-area-segmentation/Mask/3026.png
# /kaggle/input/flood-area-segmentation/Mask/1056.png
# /kaggle/input/flood-area-segmentation/Mask/1082.png
# /kaggle/input/flood-area-segmentation/Mask/2031.png
# /kaggle/input/flood-area-segmentation/Mask/3001.png
# /kaggle/input/flood-area-segmentation/Mask/3054.png
# /kaggle/input/flood-area-segmentation/Mask/28.png
# /kaggle/input/flood-area-segmentation/Mask/3088.png
# /kaggle/input/flood-area-segmentation/Mask/1043.png
# /kaggle/input/flood-area-segmentation/Mask/3023.png
# /kaggle/input/flood-area-segmentation/Mask/3093.png
# /kaggle/input/flood-area-segmentation/Mask/22.png
# /kaggle/input/flood-area-segmentation/Mask/1030.png
# /kaggle/input/flood-area-segmentation/Mask/1049.png
# /kaggle/input/flood-area-segmentation/Mask/3057.png
# /kaggle/input/flood-area-segmentation/Mask/1044.png
# /kaggle/input/flood-area-segmentation/Mask/3043.png
# /kaggle/input/flood-area-segmentation/Mask/34.png
# /kaggle/input/flood-area-segmentation/Mask/1087.png
# /kaggle/input/flood-area-segmentation/Mask/41.png
# /kaggle/input/flood-area-segmentation/Mask/1013.png
# /kaggle/input/flood-area-segmentation/Mask/1068.png
# /kaggle/input/flood-area-segmentation/Mask/3097.png
# /kaggle/input/flood-area-segmentation/Mask/1057.png
# /kaggle/input/flood-area-segmentation/Mask/2039.png
# /kaggle/input/flood-area-segmentation/Mask/2002.png
# /kaggle/input/flood-area-segmentation/Mask/2023.png
# /kaggle/input/flood-area-segmentation/Mask/1026.png
# /kaggle/input/flood-area-segmentation/Mask/3079.png
# /kaggle/input/flood-area-segmentation/Mask/3069.png
# /kaggle/input/flood-area-segmentation/Mask/7.png
# /kaggle/input/flood-area-segmentation/Mask/1075.png
# /kaggle/input/flood-area-segmentation/Mask/2050.png
# /kaggle/input/flood-area-segmentation/Mask/2019.png
# /kaggle/input/flood-area-segmentation/Mask/3091.png
# /kaggle/input/flood-area-segmentation/Mask/1051.png
# /kaggle/input/flood-area-segmentation/Mask/29.png
# /kaggle/input/flood-area-segmentation/Mask/1007.png
# /kaggle/input/flood-area-segmentation/Mask/1015.png
# /kaggle/input/flood-area-segmentation/Mask/1035.png
# /kaggle/input/flood-area-segmentation/Mask/3037.png
# /kaggle/input/flood-area-segmentation/Mask/2043.png
# /kaggle/input/flood-area-segmentation/Mask/3036.png
# /kaggle/input/flood-area-segmentation/Mask/1001.png
# /kaggle/input/flood-area-segmentation/Mask/1046.png
# /kaggle/input/flood-area-segmentation/Mask/2045.png
# /kaggle/input/flood-area-segmentation/Mask/1050.png
# /kaggle/input/flood-area-segmentation/Mask/2046.png
# /kaggle/input/flood-area-segmentation/Mask/2022.png
# /kaggle/input/flood-area-segmentation/Mask/17.png
# /kaggle/input/flood-area-segmentation/Mask/3024.png
# /kaggle/input/flood-area-segmentation/Mask/2038.png
# /kaggle/input/flood-area-segmentation/Mask/2047.png
# /kaggle/input/flood-area-segmentation/Mask/1059.png
# /kaggle/input/flood-area-segmentation/Mask/5.png
# /kaggle/input/flood-area-segmentation/Mask/3076.png
# /kaggle/input/flood-area-segmentation/Mask/3.png
# /kaggle/input/flood-area-segmentation/Mask/3094.png
# /kaggle/input/flood-area-segmentation/Mask/1011.png
# /kaggle/input/flood-area-segmentation/Mask/1061.png
# /kaggle/input/flood-area-segmentation/Mask/16.png
# /kaggle/input/flood-area-segmentation/Mask/1028.png
# /kaggle/input/flood-area-segmentation/Mask/2008.png
# /kaggle/input/flood-area-segmentation/Mask/3059.png
# /kaggle/input/flood-area-segmentation/Mask/2001.png
# /kaggle/input/flood-area-segmentation/Mask/8.png
# /kaggle/input/flood-area-segmentation/Mask/45.png
# /kaggle/input/flood-area-segmentation/Mask/24.png
# /kaggle/input/flood-area-segmentation/Mask/2014.png
# /kaggle/input/flood-area-segmentation/Mask/1066.png
# /kaggle/input/flood-area-segmentation/Mask/32.png
# /kaggle/input/flood-area-segmentation/Mask/3007.png
# /kaggle/input/flood-area-segmentation/Mask/1040.png
# /kaggle/input/flood-area-segmentation/Mask/1086.png
# /kaggle/input/flood-area-segmentation/Mask/6.png
# /kaggle/input/flood-area-segmentation/Mask/23.png
# /kaggle/input/flood-area-segmentation/Mask/3033.png
# /kaggle/input/flood-area-segmentation/Mask/3084.png
# /kaggle/input/flood-area-segmentation/Mask/3027.png
# /kaggle/input/flood-area-segmentation/Mask/3021.png
# /kaggle/input/flood-area-segmentation/Mask/1002.png
# /kaggle/input/flood-area-segmentation/Mask/1069.png
# /kaggle/input/flood-area-segmentation/Mask/3048.png
# /kaggle/input/flood-area-segmentation/Mask/1016.png
# /kaggle/input/flood-area-segmentation/Mask/2049.png
# /kaggle/input/flood-area-segmentation/Mask/3035.png
# /kaggle/input/flood-area-segmentation/Mask/3067.png
# /kaggle/input/flood-area-segmentation/Mask/3074.png
# /kaggle/input/flood-area-segmentation/Mask/44.png
# /kaggle/input/flood-area-segmentation/Mask/3000.png
# /kaggle/input/flood-area-segmentation/Mask/2010.png
# /kaggle/input/flood-area-segmentation/Mask/1021.png
# /kaggle/input/flood-area-segmentation/Mask/1065.png
# /kaggle/input/flood-area-segmentation/Mask/3009.png
# /kaggle/input/flood-area-segmentation/Mask/1053.png
# /kaggle/input/flood-area-segmentation/Mask/1052.png
# /kaggle/input/flood-area-segmentation/Mask/2025.png
# /kaggle/input/flood-area-segmentation/Mask/3073.png
# /kaggle/input/flood-area-segmentation/Mask/46.png
# /kaggle/input/flood-area-segmentation/Mask/1060.png
# /kaggle/input/flood-area-segmentation/Mask/1080.png
# /kaggle/input/flood-area-segmentation/Mask/3019.png
# /kaggle/input/flood-area-segmentation/Mask/3017.png
# /kaggle/input/flood-area-segmentation/Mask/1024.png
# /kaggle/input/flood-area-segmentation/Mask/1042.png
# /kaggle/input/flood-area-segmentation/Mask/2024.png
# /kaggle/input/flood-area-segmentation/Mask/15.png
# /kaggle/input/flood-area-segmentation/Mask/2042.png
# /kaggle/input/flood-area-segmentation/Mask/3041.png
# /kaggle/input/flood-area-segmentation/Mask/3046.png
# /kaggle/input/flood-area-segmentation/Mask/3008.png
# /kaggle/input/flood-area-segmentation/Mask/3013.png
# /kaggle/input/flood-area-segmentation/Mask/1031.png
# /kaggle/input/flood-area-segmentation/Mask/30.png
# /kaggle/input/flood-area-segmentation/Mask/27.png
# /kaggle/input/flood-area-segmentation/Mask/1058.png
# /kaggle/input/flood-area-segmentation/Mask/3063.png
# /kaggle/input/flood-area-segmentation/Mask/47.png
# /kaggle/input/flood-area-segmentation/Mask/3081.png
# /kaggle/input/flood-area-segmentation/Mask/13.png
# /kaggle/input/flood-area-segmentation/Mask/2018.png
# /kaggle/input/flood-area-segmentation/Mask/2032.png
# /kaggle/input/flood-area-segmentation/Mask/1034.png
# /kaggle/input/flood-area-segmentation/Mask/1074.png
# /kaggle/input/flood-area-segmentation/Mask/25.png
# /kaggle/input/flood-area-segmentation/Mask/3075.png
# /kaggle/input/flood-area-segmentation/Mask/2035.png
# /kaggle/input/flood-area-segmentation/Mask/0.png
# /kaggle/input/flood-area-segmentation/Mask/2033.png
# /kaggle/input/flood-area-segmentation/Mask/19.png
# /kaggle/input/flood-area-segmentation/Mask/26.png
# /kaggle/input/flood-area-segmentation/Mask/2004.png
# /kaggle/input/flood-area-segmentation/Mask/3004.png
# /kaggle/input/flood-area-segmentation/Mask/2027.png
# /kaggle/input/flood-area-segmentation/Mask/2016.png
# /kaggle/input/flood-area-segmentation/Mask/3085.png
# /kaggle/input/flood-area-segmentation/Mask/42.png
# /kaggle/input/flood-area-segmentation/Mask/3050.png
# /kaggle/input/flood-area-segmentation/Mask/3029.png
# /kaggle/input/flood-area-segmentation/Image/2008.jpg
# /kaggle/input/flood-area-segmentation/Image/1075.jpg
# /kaggle/input/flood-area-segmentation/Image/2029.jpg
# /kaggle/input/flood-area-segmentation/Image/1031.jpg
# /kaggle/input/flood-area-segmentation/Image/2021.jpg
# /kaggle/input/flood-area-segmentation/Image/1024.jpg
# /kaggle/input/flood-area-segmentation/Image/3014.jpg
# /kaggle/input/flood-area-segmentation/Image/45.jpg
# /kaggle/input/flood-area-segmentation/Image/20.jpg
# /kaggle/input/flood-area-segmentation/Image/1009.jpg
# /kaggle/input/flood-area-segmentation/Image/2028.jpg
# /kaggle/input/flood-area-segmentation/Image/6.jpg
# /kaggle/input/flood-area-segmentation/Image/2041.jpg
# /kaggle/input/flood-area-segmentation/Image/2003.jpg
# /kaggle/input/flood-area-segmentation/Image/1055.jpg
# /kaggle/input/flood-area-segmentation/Image/1026.jpg
# /kaggle/input/flood-area-segmentation/Image/3064.jpg
# /kaggle/input/flood-area-segmentation/Image/1010.jpg
# /kaggle/input/flood-area-segmentation/Image/1025.jpg
# /kaggle/input/flood-area-segmentation/Image/3085.jpg
# /kaggle/input/flood-area-segmentation/Image/1058.jpg
# /kaggle/input/flood-area-segmentation/Image/3010.jpg
# /kaggle/input/flood-area-segmentation/Image/5.jpg
# /kaggle/input/flood-area-segmentation/Image/3011.jpg
# /kaggle/input/flood-area-segmentation/Image/8.jpg
# /kaggle/input/flood-area-segmentation/Image/2011.jpg
# /kaggle/input/flood-area-segmentation/Image/3037.jpg
# /kaggle/input/flood-area-segmentation/Image/1032.jpg
# /kaggle/input/flood-area-segmentation/Image/3058.jpg
# /kaggle/input/flood-area-segmentation/Image/2020.jpg
# /kaggle/input/flood-area-segmentation/Image/3030.jpg
# /kaggle/input/flood-area-segmentation/Image/1037.jpg
# /kaggle/input/flood-area-segmentation/Image/3016.jpg
# /kaggle/input/flood-area-segmentation/Image/3017.jpg
# /kaggle/input/flood-area-segmentation/Image/30.jpg
# /kaggle/input/flood-area-segmentation/Image/1002.jpg
# /kaggle/input/flood-area-segmentation/Image/38.jpg
# /kaggle/input/flood-area-segmentation/Image/2033.jpg
# /kaggle/input/flood-area-segmentation/Image/1041.jpg
# /kaggle/input/flood-area-segmentation/Image/42.jpg
# /kaggle/input/flood-area-segmentation/Image/1071.jpg
# /kaggle/input/flood-area-segmentation/Image/1019.jpg
# /kaggle/input/flood-area-segmentation/Image/33.jpg
# /kaggle/input/flood-area-segmentation/Image/10.jpg
# /kaggle/input/flood-area-segmentation/Image/0.jpg
# /kaggle/input/flood-area-segmentation/Image/2035.jpg
# /kaggle/input/flood-area-segmentation/Image/1076.jpg
# /kaggle/input/flood-area-segmentation/Image/35.jpg
# /kaggle/input/flood-area-segmentation/Image/1018.jpg
# /kaggle/input/flood-area-segmentation/Image/3066.jpg
# /kaggle/input/flood-area-segmentation/Image/2051.jpg
# /kaggle/input/flood-area-segmentation/Image/1078.jpg
# /kaggle/input/flood-area-segmentation/Image/3077.jpg
# /kaggle/input/flood-area-segmentation/Image/1067.jpg
# /kaggle/input/flood-area-segmentation/Image/2016.jpg
# /kaggle/input/flood-area-segmentation/Image/3040.jpg
# /kaggle/input/flood-area-segmentation/Image/3025.jpg
# /kaggle/input/flood-area-segmentation/Image/1080.jpg
# /kaggle/input/flood-area-segmentation/Image/41.jpg
# /kaggle/input/flood-area-segmentation/Image/2019.jpg
# /kaggle/input/flood-area-segmentation/Image/3084.jpg
# /kaggle/input/flood-area-segmentation/Image/1012.jpg
# /kaggle/input/flood-area-segmentation/Image/1034.jpg
# /kaggle/input/flood-area-segmentation/Image/1048.jpg
# /kaggle/input/flood-area-segmentation/Image/3047.jpg
# /kaggle/input/flood-area-segmentation/Image/1084.jpg
# /kaggle/input/flood-area-segmentation/Image/3012.jpg
# /kaggle/input/flood-area-segmentation/Image/3054.jpg
# /kaggle/input/flood-area-segmentation/Image/1044.jpg
# /kaggle/input/flood-area-segmentation/Image/3006.jpg
# /kaggle/input/flood-area-segmentation/Image/1082.jpg
# /kaggle/input/flood-area-segmentation/Image/3082.jpg
# /kaggle/input/flood-area-segmentation/Image/2036.jpg
# /kaggle/input/flood-area-segmentation/Image/1054.jpg
# /kaggle/input/flood-area-segmentation/Image/1017.jpg
# /kaggle/input/flood-area-segmentation/Image/9.jpg
# /kaggle/input/flood-area-segmentation/Image/3028.jpg
# /kaggle/input/flood-area-segmentation/Image/37.jpg
# /kaggle/input/flood-area-segmentation/Image/2023.jpg
# /kaggle/input/flood-area-segmentation/Image/1.jpg
# /kaggle/input/flood-area-segmentation/Image/2046.jpg
# /kaggle/input/flood-area-segmentation/Image/3005.jpg
# /kaggle/input/flood-area-segmentation/Image/1060.jpg
# /kaggle/input/flood-area-segmentation/Image/2010.jpg
# /kaggle/input/flood-area-segmentation/Image/3086.jpg
# /kaggle/input/flood-area-segmentation/Image/1053.jpg
# /kaggle/input/flood-area-segmentation/Image/2002.jpg
# /kaggle/input/flood-area-segmentation/Image/1077.jpg
# /kaggle/input/flood-area-segmentation/Image/2040.jpg
# /kaggle/input/flood-area-segmentation/Image/46.jpg
# /kaggle/input/flood-area-segmentation/Image/3023.jpg
# /kaggle/input/flood-area-segmentation/Image/3088.jpg
# /kaggle/input/flood-area-segmentation/Image/2005.jpg
# /kaggle/input/flood-area-segmentation/Image/3036.jpg
# /kaggle/input/flood-area-segmentation/Image/44.jpg
# /kaggle/input/flood-area-segmentation/Image/1029.jpg
# /kaggle/input/flood-area-segmentation/Image/29.jpg
# /kaggle/input/flood-area-segmentation/Image/1042.jpg
# /kaggle/input/flood-area-segmentation/Image/3007.jpg
# /kaggle/input/flood-area-segmentation/Image/2047.jpg
# /kaggle/input/flood-area-segmentation/Image/3009.jpg
# /kaggle/input/flood-area-segmentation/Image/1079.jpg
# /kaggle/input/flood-area-segmentation/Image/1038.jpg
# /kaggle/input/flood-area-segmentation/Image/3039.jpg
# /kaggle/input/flood-area-segmentation/Image/1039.jpg
# /kaggle/input/flood-area-segmentation/Image/16.jpg
# /kaggle/input/flood-area-segmentation/Image/3015.jpg
# /kaggle/input/flood-area-segmentation/Image/3065.jpg
# /kaggle/input/flood-area-segmentation/Image/23.jpg
# /kaggle/input/flood-area-segmentation/Image/3027.jpg
# /kaggle/input/flood-area-segmentation/Image/7.jpg
# /kaggle/input/flood-area-segmentation/Image/1074.jpg
# /kaggle/input/flood-area-segmentation/Image/3078.jpg
# /kaggle/input/flood-area-segmentation/Image/1028.jpg
# /kaggle/input/flood-area-segmentation/Image/3001.jpg
# /kaggle/input/flood-area-segmentation/Image/28.jpg
# /kaggle/input/flood-area-segmentation/Image/22.jpg
# /kaggle/input/flood-area-segmentation/Image/1011.jpg
# /kaggle/input/flood-area-segmentation/Image/3098.jpg
# /kaggle/input/flood-area-segmentation/Image/1022.jpg
# /kaggle/input/flood-area-segmentation/Image/1023.jpg
# /kaggle/input/flood-area-segmentation/Image/3038.jpg
# /kaggle/input/flood-area-segmentation/Image/3083.jpg
# /kaggle/input/flood-area-segmentation/Image/40.jpg
# /kaggle/input/flood-area-segmentation/Image/3063.jpg
# /kaggle/input/flood-area-segmentation/Image/1066.jpg
# /kaggle/input/flood-area-segmentation/Image/3018.jpg
# /kaggle/input/flood-area-segmentation/Image/3003.jpg
# /kaggle/input/flood-area-segmentation/Image/48.jpg
# /kaggle/input/flood-area-segmentation/Image/1056.jpg
# /kaggle/input/flood-area-segmentation/Image/1086.jpg
# /kaggle/input/flood-area-segmentation/Image/3095.jpg
# /kaggle/input/flood-area-segmentation/Image/2034.jpg
# /kaggle/input/flood-area-segmentation/Image/3091.jpg
# /kaggle/input/flood-area-segmentation/Image/1081.jpg
# /kaggle/input/flood-area-segmentation/Image/24.jpg
# /kaggle/input/flood-area-segmentation/Image/3080.jpg
# /kaggle/input/flood-area-segmentation/Image/3035.jpg
# /kaggle/input/flood-area-segmentation/Image/1043.jpg
# /kaggle/input/flood-area-segmentation/Image/1064.jpg
# /kaggle/input/flood-area-segmentation/Image/3057.jpg
# /kaggle/input/flood-area-segmentation/Image/2001.jpg
# /kaggle/input/flood-area-segmentation/Image/2048.jpg
# /kaggle/input/flood-area-segmentation/Image/3021.jpg
# /kaggle/input/flood-area-segmentation/Image/1087.jpg
# /kaggle/input/flood-area-segmentation/Image/31.jpg
# /kaggle/input/flood-area-segmentation/Image/3074.jpg
# /kaggle/input/flood-area-segmentation/Image/2042.jpg
# /kaggle/input/flood-area-segmentation/Image/43.jpg
# /kaggle/input/flood-area-segmentation/Image/2017.jpg
# /kaggle/input/flood-area-segmentation/Image/2024.jpg
# /kaggle/input/flood-area-segmentation/Image/3050.jpg
# /kaggle/input/flood-area-segmentation/Image/3041.jpg
# /kaggle/input/flood-area-segmentation/Image/13.jpg
# /kaggle/input/flood-area-segmentation/Image/2031.jpg
# /kaggle/input/flood-area-segmentation/Image/3049.jpg
# /kaggle/input/flood-area-segmentation/Image/1006.jpg
# /kaggle/input/flood-area-segmentation/Image/1035.jpg
# /kaggle/input/flood-area-segmentation/Image/3024.jpg
# /kaggle/input/flood-area-segmentation/Image/1007.jpg
# /kaggle/input/flood-area-segmentation/Image/3044.jpg
# /kaggle/input/flood-area-segmentation/Image/3052.jpg
# /kaggle/input/flood-area-segmentation/Image/1036.jpg
# /kaggle/input/flood-area-segmentation/Image/1027.jpg
# /kaggle/input/flood-area-segmentation/Image/3019.jpg
# /kaggle/input/flood-area-segmentation/Image/1068.jpg
# /kaggle/input/flood-area-segmentation/Image/1051.jpg
# /kaggle/input/flood-area-segmentation/Image/1050.jpg
# /kaggle/input/flood-area-segmentation/Image/3026.jpg
# /kaggle/input/flood-area-segmentation/Image/3068.jpg
# /kaggle/input/flood-area-segmentation/Image/2043.jpg
# /kaggle/input/flood-area-segmentation/Image/3060.jpg
# /kaggle/input/flood-area-segmentation/Image/1069.jpg
# /kaggle/input/flood-area-segmentation/Image/32.jpg
# /kaggle/input/flood-area-segmentation/Image/1045.jpg
# /kaggle/input/flood-area-segmentation/Image/3053.jpg
# /kaggle/input/flood-area-segmentation/Image/1059.jpg
# /kaggle/input/flood-area-segmentation/Image/2037.jpg
# /kaggle/input/flood-area-segmentation/Image/3051.jpg
# /kaggle/input/flood-area-segmentation/Image/3043.jpg
# /kaggle/input/flood-area-segmentation/Image/17.jpg
# /kaggle/input/flood-area-segmentation/Image/2027.jpg
# /kaggle/input/flood-area-segmentation/Image/26.jpg
# /kaggle/input/flood-area-segmentation/Image/2018.jpg
# /kaggle/input/flood-area-segmentation/Image/39.jpg
# /kaggle/input/flood-area-segmentation/Image/3073.jpg
# /kaggle/input/flood-area-segmentation/Image/1047.jpg
# /kaggle/input/flood-area-segmentation/Image/1063.jpg
# /kaggle/input/flood-area-segmentation/Image/3090.jpg
# /kaggle/input/flood-area-segmentation/Image/1000.jpg
# /kaggle/input/flood-area-segmentation/Image/3094.jpg
# /kaggle/input/flood-area-segmentation/Image/15.jpg
# /kaggle/input/flood-area-segmentation/Image/3097.jpg
# /kaggle/input/flood-area-segmentation/Image/3046.jpg
# /kaggle/input/flood-area-segmentation/Image/1013.jpg
# /kaggle/input/flood-area-segmentation/Image/12.jpg
# /kaggle/input/flood-area-segmentation/Image/3096.jpg
# /kaggle/input/flood-area-segmentation/Image/1004.jpg
# /kaggle/input/flood-area-segmentation/Image/2038.jpg
# /kaggle/input/flood-area-segmentation/Image/3075.jpg
# /kaggle/input/flood-area-segmentation/Image/3029.jpg
# /kaggle/input/flood-area-segmentation/Image/1040.jpg
# /kaggle/input/flood-area-segmentation/Image/11.jpg
# /kaggle/input/flood-area-segmentation/Image/2039.jpg
# /kaggle/input/flood-area-segmentation/Image/2014.jpg
# /kaggle/input/flood-area-segmentation/Image/1083.jpg
# /kaggle/input/flood-area-segmentation/Image/3045.jpg
# /kaggle/input/flood-area-segmentation/Image/1062.jpg
# /kaggle/input/flood-area-segmentation/Image/2030.jpg
# /kaggle/input/flood-area-segmentation/Image/34.jpg
# /kaggle/input/flood-area-segmentation/Image/3062.jpg
# /kaggle/input/flood-area-segmentation/Image/3072.jpg
# /kaggle/input/flood-area-segmentation/Image/27.jpg
# /kaggle/input/flood-area-segmentation/Image/1003.jpg
# /kaggle/input/flood-area-segmentation/Image/2006.jpg
# /kaggle/input/flood-area-segmentation/Image/1070.jpg
# /kaggle/input/flood-area-segmentation/Image/2013.jpg
# /kaggle/input/flood-area-segmentation/Image/3033.jpg
# /kaggle/input/flood-area-segmentation/Image/1072.jpg
# /kaggle/input/flood-area-segmentation/Image/21.jpg
# /kaggle/input/flood-area-segmentation/Image/4.jpg
# /kaggle/input/flood-area-segmentation/Image/2012.jpg
# /kaggle/input/flood-area-segmentation/Image/1033.jpg
# /kaggle/input/flood-area-segmentation/Image/3002.jpg
# /kaggle/input/flood-area-segmentation/Image/3004.jpg
# /kaggle/input/flood-area-segmentation/Image/1085.jpg
# /kaggle/input/flood-area-segmentation/Image/1014.jpg
# /kaggle/input/flood-area-segmentation/Image/3.jpg
# /kaggle/input/flood-area-segmentation/Image/1049.jpg
# /kaggle/input/flood-area-segmentation/Image/3032.jpg
# /kaggle/input/flood-area-segmentation/Image/36.jpg
# /kaggle/input/flood-area-segmentation/Image/3089.jpg
# /kaggle/input/flood-area-segmentation/Image/3013.jpg
# /kaggle/input/flood-area-segmentation/Image/3093.jpg
# /kaggle/input/flood-area-segmentation/Image/1001.jpg
# /kaggle/input/flood-area-segmentation/Image/3067.jpg
# /kaggle/input/flood-area-segmentation/Image/1030.jpg
# /kaggle/input/flood-area-segmentation/Image/3008.jpg
# /kaggle/input/flood-area-segmentation/Image/2022.jpg
# /kaggle/input/flood-area-segmentation/Image/1008.jpg
# /kaggle/input/flood-area-segmentation/Image/2032.jpg
# /kaggle/input/flood-area-segmentation/Image/1020.jpg
# /kaggle/input/flood-area-segmentation/Image/3076.jpg
# /kaggle/input/flood-area-segmentation/Image/3034.jpg
# /kaggle/input/flood-area-segmentation/Image/2050.jpg
# /kaggle/input/flood-area-segmentation/Image/2009.jpg
# /kaggle/input/flood-area-segmentation/Image/3092.jpg
# /kaggle/input/flood-area-segmentation/Image/1073.jpg
# /kaggle/input/flood-area-segmentation/Image/3079.jpg
# /kaggle/input/flood-area-segmentation/Image/19.jpg
# /kaggle/input/flood-area-segmentation/Image/47.jpg
# /kaggle/input/flood-area-segmentation/Image/3048.jpg
# /kaggle/input/flood-area-segmentation/Image/3087.jpg
# /kaggle/input/flood-area-segmentation/Image/3020.jpg
# /kaggle/input/flood-area-segmentation/Image/1065.jpg
# /kaggle/input/flood-area-segmentation/Image/2007.jpg
# /kaggle/input/flood-area-segmentation/Image/14.jpg
# /kaggle/input/flood-area-segmentation/Image/18.jpg
# /kaggle/input/flood-area-segmentation/Image/2045.jpg
# /kaggle/input/flood-area-segmentation/Image/1052.jpg
# /kaggle/input/flood-area-segmentation/Image/3081.jpg
# /kaggle/input/flood-area-segmentation/Image/3061.jpg
# /kaggle/input/flood-area-segmentation/Image/3055.jpg
# /kaggle/input/flood-area-segmentation/Image/2015.jpg
# /kaggle/input/flood-area-segmentation/Image/2053.jpg
# /kaggle/input/flood-area-segmentation/Image/3069.jpg
# /kaggle/input/flood-area-segmentation/Image/2025.jpg
# /kaggle/input/flood-area-segmentation/Image/2052.jpg
# /kaggle/input/flood-area-segmentation/Image/2049.jpg
# /kaggle/input/flood-area-segmentation/Image/1005.jpg
# /kaggle/input/flood-area-segmentation/Image/2044.jpg
# /kaggle/input/flood-area-segmentation/Image/49.jpg
# /kaggle/input/flood-area-segmentation/Image/2004.jpg
# /kaggle/input/flood-area-segmentation/Image/3071.jpg
# /kaggle/input/flood-area-segmentation/Image/1046.jpg
# /kaggle/input/flood-area-segmentation/Image/3056.jpg
# /kaggle/input/flood-area-segmentation/Image/3042.jpg
# /kaggle/input/flood-area-segmentation/Image/1057.jpg
# /kaggle/input/flood-area-segmentation/Image/2.jpg
# /kaggle/input/flood-area-segmentation/Image/3022.jpg
# /kaggle/input/flood-area-segmentation/Image/1061.jpg
# /kaggle/input/flood-area-segmentation/Image/1016.jpg
# /kaggle/input/flood-area-segmentation/Image/2026.jpg
# /kaggle/input/flood-area-segmentation/Image/3070.jpg
# /kaggle/input/flood-area-segmentation/Image/3031.jpg
# /kaggle/input/flood-area-segmentation/Image/1021.jpg
# /kaggle/input/flood-area-segmentation/Image/1015.jpg
# /kaggle/input/flood-area-segmentation/Image/25.jpg
# /kaggle/input/flood-area-segmentation/Image/3000.jpg
# /kaggle/input/flood-area-segmentation/Image/3059.jpg

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import numpy as np
import os
# /kaggle/input/flood-area-segmentation
# Image
# Mask
path = '/kaggle/input/flood-area-segmentation/'
class SegmentationDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_files = sorted(os.listdir(os.path.join(root_dir, 'Image')))
        self.mask_files = sorted(os.listdir(os.path.join(root_dir, 'Mask')))

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image_path = os.path.join(self.root_dir, 'Image', self.image_files[idx])
        mask_path = os.path.join(self.root_dir, 'Mask', self.mask_files[idx])
        image = Image.open(image_path).convert('RGB')
        mask = Image.open(mask_path)
        #image = np.array(image)
        #mask = np.array(mask)
        #mask[mask > 0] = 1  # Convert mask to binary
        mask = self.transform(mask)
        #mask = torch.where( mask>0, torch.tensor(1), torch.tensor(0))
        image = self.transform(image)
        return image, mask

# Define the data transformations
data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Define the dataset and data loader
train_dataset = SegmentationDataset(root_dir=path, transform=data_transforms)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=1)

# %%
import torch.nn as nn
import torch.nn.functional as F

class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)

class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # Upscaling with bilinear interpolation
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            self.up = nn.ConvTranspose2d(in_channels // 2, in_channels // 2, kernel_size=2, stride=2)

        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # Pad x2 to match the shape of x1
        diffX = x2.size()[2] - x1.size()[2]
        diffY = x2.size()[3] - x1.size()[3]
        x1 = F.pad(x1, (diffY // 2, diffY - diffY // 2,
                        diffX // 2, diffX - diffX // 2))
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self, n_channels, n_classes, bilinear=True):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        # Define the encoder path
        self.conv1 = DoubleConv(n_channels, 64)
        #self.conv1 = torch.nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        self.down4 = Down(512, 1024 // 2)

        # Define the decoder path
        self.up1 = Up(1024, 512 // 2, bilinear)
        self.up2 = Up(512, 256 // 2, bilinear)
        self.up3 = Up(256, 128 // 2, bilinear)
        self.up4 = Up(128, 64, bilinear)
        self.outconv = OutConv(64, n_classes)

    def forward(self, x):
        # Encoder path
        x1 = self.conv1(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)

        # Decoder path
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)

        # Output
        x = self.outconv(x)
        return x

# %%
import torch.optim as optim
import torch.nn.functional as F

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = UNet(n_channels=3, n_classes=1).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
num_epochs = 1
for epoch in range(num_epochs):
    running_loss = 0.0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        #print(data.shape)
        optimizer.zero_grad()
        output = model(data)
        #output = output.to(torch.long)
        #target = target .to(torch.long)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print('Epoch {} loss: {:.4f}'.format(epoch+1, running_loss))
# Out:
# Epoch 1 loss: 4.6522

# %%
torch.save(model.state_dict(), 'unet.pth')
